# %% [markdown]
# <a href="https://colab.research.google.com/github/maa929/4105/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/maa929/4105/main/D3.csv'
df = pd.read_csv(url)

x1 = df.values[:, 0]
x2 = df.values[:, 1]
x3 = df.values[:, 2]
y = df.values[:, 3]
m = len(y)
n1 = len(x1)
n2 = len(x2)
n3 = len(x3)
X_0 = np.ones((m, 1))
X_1 = x1.reshape(m, 1)
X_2 = x2.reshape(m, 1)
X_3 = x3.reshape(m, 1)
X = np.hstack((X_0, X_1))
theta  = np.zeros(2)

def compute_cost(X, y, theta):
  predictions = X.dot(theta)
  errors = np.subtract(predictions, y)
  sqrErrors = np.square(errors)
  J = 1 / (2 * m) * np.sum(sqrErrors)
  return J

def gradient_descent(X, y, theta, alpha, iterations):
  m = len(y)  # Number of training examples
  cost_history = np.zeros(iterations)

  for i in range(iterations):
      predictions = X.dot(theta)
      errors = np.subtract(predictions, y)
      sum_delta = (alpha / m) * X.transpose().dot(errors)
      theta -= sum_delta
      cost_history[i] = compute_cost(X, y, theta)

  return theta, cost_history

iterations = 1500
alpha = 0.01
theta, cost_history = gradient_descent(X, y, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)

plt.scatter(X[:, 1], y, color='red', marker='+', label='Training Data')
plt.plot(X[:, 1], X.dot(theta), color='green', label='Linear Regression')
plt.grid(True)
plt.title('Linear Regression Fit for input X1')
plt.legend()
# Out:
# Final value of theta = [ 5.71850653 -1.9568206 ]
# cost_history = [5.48226715 5.44290965 5.40604087 ... 0.99063932 0.99061433 0.99058944]

# %%
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.grid(True)
plt.title('Convergence of gradient descent for X1')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent for X1')

# %%
url = 'https://raw.githubusercontent.com/maa929/4105/main/D3.csv'
df = pd.read_csv(url)

x1 = df.values[:, 0]
x2 = df.values[:, 1]
x3 = df.values[:, 2]
y = df.values[:, 3]
m = len(y)
n1 = len(x1)
n2 = len(x2)
n3 = len(x3)
X_0 = np.ones((m, 1))
X_1 = x1.reshape(m, 1)
X_2 = x2.reshape(m, 1)
X_3 = x3.reshape(m, 1)
X = np.hstack((X_0, X_2))
theta  = np.zeros(2)

def compute_cost(X, y, theta):
  predictions = X.dot(theta)
  errors = np.subtract(predictions, y)
  sqrErrors = np.square(errors)
  J = 1 / (2 * m) * np.sum(sqrErrors)
  return J

def gradient_descent(X, y, theta, alpha, iterations):
  m = len(y)  # Number of training examples
  cost_history = np.zeros(iterations)

  for i in range(iterations):
      predictions = X.dot(theta)
      errors = np.subtract(predictions, y)
      sum_delta = (alpha / m) * X.transpose().dot(errors)
      theta -= sum_delta
      cost_history[i] = compute_cost(X, y, theta)

  return theta, cost_history

iterations = 1500
alpha = 0.01
theta, cost_history = gradient_descent(X, y, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)

plt.scatter(X[:, 1], y, color='red', marker='+', label='Training Data')
plt.plot(X[:, 1], X.dot(theta), color='green', label='Linear Regression')
plt.grid(True)
plt.title('Linear Regression Fit for input X2')
plt.legend()
# Out:
# Final value of theta = [0.71988473 0.56390334]
# cost_history = [5.29831663 5.09909109 4.92356115 ... 3.5993997  3.59939955 3.5993994 ]

# %%
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.grid(True)
plt.title('Convergence of gradient descent for X2')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent for X2')

# %%
url = 'https://raw.githubusercontent.com/maa929/4105/main/D3.csv'
df = pd.read_csv(url)

x1 = df.values[:, 0]
x2 = df.values[:, 1]
x3 = df.values[:, 2]
y = df.values[:, 3]
m = len(y)
n1 = len(x1)
n2 = len(x2)
n3 = len(x3)
X_0 = np.ones((m, 1))
X_1 = x1.reshape(m, 1)
X_2 = x2.reshape(m, 1)
X_3 = x3.reshape(m, 1)
X = np.hstack((X_0, X_3))
theta  = np.zeros(2)

def compute_cost(X, y, theta):
  predictions = X.dot(theta)
  errors = np.subtract(predictions, y)
  sqrErrors = np.square(errors)
  J = 1 / (2 * m) * np.sum(sqrErrors)
  return J

def gradient_descent(X, y, theta, alpha, iterations):
  m = len(y)  # Number of training examples
  cost_history = np.zeros(iterations)

  for i in range(iterations):
      predictions = X.dot(theta)
      errors = np.subtract(predictions, y)
      sum_delta = (alpha / m) * X.transpose().dot(errors)
      theta -= sum_delta
      cost_history[i] = compute_cost(X, y, theta)

  return theta, cost_history

iterations = 1500
alpha = 0.01
theta, cost_history = gradient_descent(X, y, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)

plt.scatter(X[:, 1], y, color='red', marker='+', label='Training Data')
plt.plot(X[:, 1], X.dot(theta), color='green', label='Linear Regression')
plt.grid(True)
plt.title('Linear Regression Fit for input X3')
plt.legend()
# Out:
# Final value of theta = [ 2.78048129 -0.48451631]
# cost_history = [5.40768785 5.30397076 5.21178297 ... 3.63053597 3.6305311  3.63052625]

# %%
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.grid(True)
plt.title('Convergence of gradient descent for X3')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent for X3')

# %%
url = 'https://raw.githubusercontent.com/maa929/4105/main/D3.csv'
df = pd.read_csv(url)

x_total = df.values[:, (0,1,2)]
y = df.values[:, 3]
m = len(y)
X_0 = np.ones((m, 1))
X_1 = x_total.reshape(m, 3)
X = np.hstack((X_0, X_1))
theta  = np.zeros(4)

def compute_cost(X, y, theta):
  predictions = X.dot(theta)
  errors = np.subtract(predictions, y)
  sqrErrors = np.square(errors)
  J = 1 / (2 * m) * np.sum(sqrErrors)
  return J

def gradient_descent(X, y, theta, alpha, iterations):
  m = len(y)  # Number of training examples
  cost_history = np.zeros(iterations)

  for i in range(iterations):
      predictions = X.dot(theta)
      errors = np.subtract(predictions, y)
      sum_delta = (alpha / m) * X.transpose().dot(errors)
      theta -= sum_delta
      cost_history[i] = compute_cost(X, y, theta)

  return theta, cost_history

iterations = 1500
alpha = 0.05
theta, cost_history = gradient_descent(X, y, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)

plt.scatter(X[:, 1], y, color='red', marker='+', label='Training Data')
plt.plot(X[:, 1], X.dot(theta), color='green', label='Linear Regression')
plt.grid(True)
plt.title('Linear Regression Fit for input x_total')
plt.legend()
# Out:
# Final value of theta = [ 5.31128136 -2.0033116   0.5330402  -0.26517886]
# cost_history = [4.35632837 3.99754934 3.73994659 ... 0.73846469 0.73846469 0.73846469]

# %%
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.grid(True)
plt.title('Convergence of gradient descent for x_total')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent for x_total')

# %%
h1 = theta[0] + theta[1]*(1) + theta[2]*(1) + theta[3]*(1)
display(h1)
h2 = theta[0] + theta[1]*(2) + theta[2]*(0) + theta[3]*(4)
display(h2)
h3 = theta[0] + theta[1]*(3) + theta[2]*(2) + theta[3]*(1)
display(h3)
# Out:
# 3.575831095534636
# 0.2439427039331008
# 0.10224809362461551
